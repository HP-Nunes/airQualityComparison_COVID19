# %% [markdown]
# <div class="cover">
#     <div class= "cover-logo">
#                 <img src="https://live.staticflickr.com/3527/3221454835_6748bef6fe_b.jpg" style="height: 250px; width: 700px; float:right" alt="LaCroix Design Co." />
# <br>
# <br>
# <br>
# Author:          Hadrien Picq <br>
# Email:           contact@hpnunes.com <br>
# Website:     www.hpnunes.com <br>
# Keywords:        Proposal, Data Analysis, Fine Particulate Pollution <br>
# Date:            May 13th, 2020 <br>
# </div>
# <br>
# <br>
# <br>
# <p style="font-size: 0.9rem;font-style: italic;float: right;"><a href="https://www.flickr.com/photos/81241165@N00/3221454835">"SF from the sky"</a><span> by <a href="https://www.flickr.com/photos/81241165@N00">NBphotostream</a></span> is licensed under <a href="https://creativecommons.org/licenses/by/2.0/?ref=ccsearch&atype=html" style="margin-right: 5px;">CC BY 2.0</a><a href="https://creativecommons.org/licenses/by/2.0/?ref=ccsearch&atype=html" target="_blank" rel="noopener noreferrer" style="display: inline-block;white-space: none;margin-top: 2px;margin-left: 3px;height: 22px !important;"><img style="height: inherit;margin-right: 3px;display: inline-block;" src="https://search.creativecommons.org/static/img/cc_icon.svg" /><img style="height: inherit;margin-right: 3px;display: inline-block;" src="https://search.creativecommons.org/static/img/cc-by_icon.svg" /></a></p>
# <br>
# <br>
#
# # Was There an Effect on Fine Particulate Pollution During the COVID-19 'Shelter-in-Place' Period in San Francisco?
#
# #### Prepared For: Solon F. (Fred) Blundell, Ph.D., Ed.M.
# *Probability and Statistics 30809-541*
# <br>*City College San Francisco*
# <br><em>This work is unfunded and pedagogical in intent</em>
# </div>

# %% [markdown]
# # Introduction
#
# <br>
# Particulate Matter is a mixture of solid particles and liquid droplets in the air of varied size and shape: PM10—coarse particulate matter, PM2.5—fine particulate matter, and Ultrafine particles. While PM10 (dust or smoke) may be irritating to the mucous membranes, PM2.5 poses a significant health risk because they are commonly inhaled into the lungs and bloodstream, causing serious respiratory health issues and posing a significant health risks for people with asthma and heart conditions. In order to systematically assess the exposure of the general population to the hazards of air pollution, air quality monitoring is required, often under a regulatory mandate (Borghi et al, 2017).
#
# According to the American Lung Association's State of the Air Report for 2019, the San Jose-San Francisco-Oakland metropolitan area ranks as high as third out of 216 metropolitan areas for 24-hour particle pollution and fifth for annual particle pollution out of 204 metropolitan areas.
# (http://www.stateoftheair.org/city-rankings/msas/san-jose-san-francisco-oakland-ca.html#pmann)
#
# The purpose of this project is to explore whether 'shelter-in-place' orders due to COVID-19 for the city of San Francisco has had a noticeable impact on air quality. This is based on the presumption that suspended economic activities and a population instructed to self-quarantine has had the effect of reducing activities which contribute to fine particle pollution. Such activities include vehicular traffic, construction, and manufacturing.
#
# The parameters of this research are as follow:
# * A focus on 24-hour PM2.5 particle measurements (measured in µg/m3);
# * An overall temporal scope from January 1st - April 30th;
# * The confinement period is defined from March 17th to April 30th;
# * A baseline comparison with 2019 and 2018 measurements for that same period of measurements;
#
# (https://abc7news.com/timeline-of-coronavirus-us-coronvirus-bay-area-sf/6047519/)
#
# ## Data source & Measurement Methods
# The raw data measurements were pulled using [OpenAQ's API through Amazon Web Services](insert footnote); the original data source is attributed to the U.S. EPA. There is a single stationary air quality monitoring station which provides all measurements of Fine Particulate concentrations in the city of San Francisco.
# [Insert blurb about collection methodology]
#
# ## Accuracy of the Raw Measurements
# [Refer to AirNow/EPA/BAAQMD documentation]
#
# ## Sampling Representation
#  How was a representative sample obtained? In other words, how
# did you select which small set of individuals are being used as representatives
# of the whole population? You should use a \Simple
# Random Sample." If you have done this, explain to the reader
# what this means and how you accomplished it. Did you use a
# random process (perhaps the RANDBETWEEN() function in Microsoft
# Excel) to select members of the sample? Did every subset
# of the population have an equal chance to be selected?
#  Are there any characteristics of the sample that may not be representative
# of the population as a whole? Look for outliers, and see
# if the margins of error on those data are unusually large, casting
# doubt on their accuracy. You want to determine whether there
# may be a few extreme measurements in your sample that would
# cause the sample mean to dier a lot from the population mean.
# 3. Add the appendix. The appendix is the part at the end of the paper
# that will not be of interest to most readers, but it needs to be there \for
# the record." It will include the listing of the raw data, and some other
# items to be added later in the semester. Copy and paste the table
# of data from the spreadsheet that you should have submitted for an
# earlier assignment. Adjust the formatting to make it look professional.
# The appendix belongs after the main body of the paper. If you are using
# endnotes instead of footnotes, they come after the appendix. Otherwise
# 220 CHAPTER 3. PRODUCING DATA
# no part of the paper should come after the appendix.

# %% [markdown]
# # Statistical Summary
#
# ## Percent Frequency Density Histogram
#
# Using Sturge's rule, for a dataset with n = 93 (24-hour PM2.5 particle measurements), the number of classes will be:
#
# K = 1 + 3.322 * log(93) = 7.54 ≅ 8.
# (https://www.vosesoftware.com/riskwiki/Sturgesrule.php)
#
# Range of the distribution: Max(n) - Min(n) = 13.905 µg/m3 - 0.772 µg/m3 = 13.133 µg/m3
#
# Class width: 13.133 µg/m3 / 8 = 1.642 µg/m3 / Class
#
#
# ![image info](./assets/outputs/freqhist.png)
#
#
# ## Measures Of Center
#
# |Mean (µg/m3)|Median (µg/m3)|Mode (µg/m3)|
# |----------|:--------:|------:|
# |  |          |   |
#
# ## Measures Of Dispersion
#
# |Standard Deviation (µg/m3)|Interquartile Range (µg/m3)|Range (µg/m3)|
# |----------|:--------:|------:|
# |  |          |   |
#
# ## Five Number Summary & Boxplot
# |Minimum (µg/m3)|Q1 (µg/m3)|Q2 (µg/m3)|Q3 (µg/m3)|Maximum (µg/m3)|
# |----------|:--------:|:--------:|:--------:|------:|
# |  |        |   |   |   |
#
# ![image info](./assets/outputs/boxplot.png)
#
# ## Shape of the Distribution
# Write a paragraph about the shape of the distribution.
# The purpose of this paragraph is to determine whether the distribution is
# or is not \roughly normal". For this purpose, we will consider a distribution
# to be roughly normal if it is symmetrical, unimodal, and has no outliers. We
# will use the \1.5IQR rule" to identify outliers.
# When a distribution is not roughly normal, a larger sample may be needed
# to accurately estimate population parameters or to test hypotheses. If the
# 226 CHAPTER 3. PRODUCING DATA
# data includes outliers, and if these are due to errors in measurement, then
# inferences from the data may be incorrect.
# Begin with a topic sentence that addresses the main question: is the
# distribution roughly normal? Then include answers to the following questions
# regarding the distribution in order to provide evidence supporting your claim
# about the main question.
#  What does the distribution look like?
# Is it symmetrical or skewed? How many modes are there?
#  What criterion are you using to identify outliers?
# Tell the reader that you are using the 1.5IQR rule, and explain how
# this works. Tell the reader how large and how small a datum must be
# to be considered an outlier in your data set.
#  Are there any outliers?
# Name the individual outliers. Check the margin of error for each of
# them to help you decide whether these resulted from errors in measurement.
#  Why do you think the outliers occurred?
# Was there an error in measurement?

# %%
# Frequency Histogram

PurpleAir <- read.csv("assets/purpleAir_byUniqueLocations.csv")
# PurpleAir
# PurpleAir$PM2.5_ATM_ug.m3
min(PurpleAir$PM2.5_ATM_ug.m)

# sd(PurpleAir$measurement_count)
# airNow20_24hr$value <- as.numeric(airNow20_24hr$value)

classes = c(0.772,2.414,4.056,5.698,7.34,8.982,10.624,12.266,13.906)
h = hist(PurpleAir$PM2.5_ATM_ug.m3, breaks = classes, labels = labs,
    xlab = "PM2.5 Concentration (µg/m3)", ylab = "count",
    col = "purple", xlim= c(1,20),
    main = 'Percent Frequency Density Histogram,
    24-hour PM2.5 Measurements for January - April 2020', w = '1.642')

h$density = h$counts/sum(h$counts)*100
labs <- paste(round(h$density), "%", sep="")

plot(h,freq=FALSE,labels = labs ,main='Histogram with Percentage Frequencies')


# Boxplot

boxplot(PurpleAir$PM2.5_ATM_ug.m3,
main = "Mean 24hr-PM2.5 Concentration (µg/m3) in San Francisco, Jan-Apr 2020",
xlab = "µg/m3",
ylab = "PM2.5",
col = "purple",
border = "brown",
horizontal = TRUE,
notch = TRUE
)
# Out:
# [1] 0.7724736
# Plot with title “Percent Frequency Density Histogram,
#     24-hour PM2.5 Measurements for January - April 2020”
# Plot with title “Histogram with Percentage Frequencies”
# Plot with title “Mean 24hr-PM2.5 Concentration (µg/m3) in San Francisco, Jan-Apr 2020”

# %%
# ## Percent frequency
# h = hist(PurpleAir$PM2.5_ATM_ug.m3, breaks=classes, col = "pink", plot=FALSE) # or hist(x,plot=FALSE) to avoid the plot of the histogram
# h$density = h$counts/sum(h$counts)*100
# labs <- paste(round(h$density), "%", sep="")

# plot(h,freq=FALSE,labels = labs ,main='Histogram with Percentage Frequencies')

# %% [markdown]
# # Estimating the Population Mean

# %%
The purpose of these paragraphs is to estimate the population mean of
the variable in your research based on your sample data. Because the estimate
is only based on a sample (as the population is too large to allow the
analysis of data from every member)the estimate will not be exactly correct.
A condence interval is a range of possible values for the population mean,
constructed based on a random sample using a method (Gosset's T-Interval)
that will frequently produce an interval that acutally contains the population
mean.
1. Begin with a short paragraph either indicating why the use of Gosset's
T -interval method is or is not valid in the context of this research. Its
use will be justied either by the large sample size (n > 32), or would
be justied with even a small sample if the distribution was found to
be roughly normal.
2. Then write a second short paragrah in which the topic sentence is
a statement that there is 90% condence that the population mean is
between and based on Gosset's T-Interval method. Explain
a little bit about how this was calculated, and include the details of the
calculation in the appendix of the paper, includingthe critical t-score
t*, the margin of error E, and the boundaries of the condence interval.
(Note that the calculations are explained in a previous section of
Test the hypothesis for your project.
Before you can get started on this activity, your instructor must provide
you with a null hypothesis and an alternative hypothesis to test it against.
5.16. THIRD DRAFT OF THE PROJECT 529
These hypotheses may already have been stated in the project proposal,
and/or the instructor may create unique hypotheses for each student, based
on earlier steps in the project.
The nal result is either that the given hypothesis has been rejected by
Gosset's T-test with 99% condence, or that less than this required level of
condence has been achieved.
1. Use Gosset's T distribution to calculate the P-Value of your sample
data under the null hypothesis. (The P-Value is the percentage of all
possible simple random samples that, if the null hypothesis were true,
you would give a sample mean so distant as yours was from the null
hypothesis.)
2. Use the P-value to decide whether your data is signicant enough to
reject the given hypothesis with 99% condence.
3. Add a paragraph to present your conclusion about whether the data
does or does not provide signicant evidence against the null hypothesis
. Include the following:
 the null and alternative hypotheses,
 the type of test being performed (Gosset's T-test),
 the signicance level of the test (1%),
 the P-Value you obtained, and
 the conclusion that you reached.
 comments on the reliability of the result. (Are there characteristics
of the data that cast doubt on the validity of the method used?)
4. Include the P-Value calculations in the appendix of your paper.
